# %%
import matplotlib.pyplot as plt
months=["Jan","Feb","March","April"]
students=[85,90,95,88]
plt.plot(months,students)
plt.title("Student attendance trend")
plt.xlabel("Months")
plt.ylabel("Students")
plt.show()
